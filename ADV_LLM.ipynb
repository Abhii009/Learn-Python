# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhii009/Learn-Python/blob/main/ADV_LLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Advance LLMs
# Use Cases:
# 1. Structured Output from LLMS(make LLms output machine readable for downstream Task Like UI Rendering, and database storage)
''' Key concepts:-
     a. Prompting for JSON, CSV, YAML, formates
     b. use for delimeiters to ensure the clean outputs
     c. schema defination via prompt'''

# 2. Error Handing For API(Insure Applicatin's Stability when calling LLMs or other APIs)
''' Key concepts:-
     a. use try/concepts blocks for network/API failure
     b. Long API Error Debugging
     c. Retry Logic with exponential backoff for production '''

# 3. Common LLMsmUSe case in Application
''' Key Areas:-
     a. Content Generation(Blog, product description)
     b. Chatbots(Custeomer Service/assistant)
     c. Summerization(Legal Docs, News)
     d. Code generation(Boilerplate, explainatin)
     e. Data extraction (pull structured info from unstructured text)'''
# Out:
# ' Key Areas:-\n     a. Content Generation(Blog, product description)\n     b. Chatbots(Custeomer Service/assistant)\n     c. Summerization(Legal Docs, News)\n     d. Code generation(Boilerplate, explainatin)\n     e. Data extraction (pull structured info from unstructured text)'

# %%
for i in range (1-100):
   print("Abhishek")

# %%
import openai
from openai import OpenAI

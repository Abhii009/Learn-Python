# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhii009/Learn-Python/blob/main/Day11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
l = [10,20,30,40]
df = pd.Series(l)
print(df)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
df = pd.Series(data = l, index =["nikhil","gungun","abhii","hello"])
print(df)
# Out:
# nikhil    10
# gungun    20
# abhii     30
# hello     40
# dtype: int64

# %%
d= {'nikhil':10,"devendra":20,"gungun":30,"abhii":40}
df = pd.Series(data=d)
print(df)
# Out:
# nikhil      10
# devendra    20
# gungun      30
# abhii       40
# dtype: int64

# %%
# pd is nickname of pandas
import pandas as pd
l = [10,20,30,40,50] # list
df = pd.Series(l) # use list in pd
print(df)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
# example data
df = pd.Series(data=l)
print(df)

# example index
df = pd.Series(data=l , index=['nikhil','devendra','raj','hello','unknown'])
print(df)

# example key = index | value = value
d = {'nikhil':10,'devendra':20,'raj':30,'hello':40,'unknown':50}
df = pd.Series(data=d)
print(df)

# experiment
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# nikhil      10
# devendra    20
# raj         30
# hello       40
# unknown     50
# dtype: int64
# nikhil      10
# devendra    20
# raj         30
# hello       40
# unknown     50
# dtype: int64

# %%
#2d
import pandas as pd
data = {
    "name": ["nikhil","gungun","devendra"],
     "age": [10,20,30]
}

df = pd.Series(data)
print(df)


df = pd.DataFrame(data)
print(df)
# Out:
# name    [nikhil, gungun, devendra]
# age                   [10, 20, 30]
# dtype: object
#        name  age
# 0    nikhil   10
# 1    gungun   20
# 2  devendra   30

# %%
#github csv
import pandas as pd

url   =   "https://raw.githubusercontent.com/Abhii009/Learn-Python/main/file.csv"
df = pd.read_csv(url)
print(df)
# Out:
#        name gender
# 0    nikhil   male
# 1       raj   male
# 2  devendra   male
# 3     hello   male

# %%
import pandas as pd
data = [["nikhil",10],["devendra",20],["raj",30],["hello",40]]
df = pd.DataFrame(data , columns = ["name",'age'])
print(df)


# add index name
df = pd.DataFrame(data , columns = ["name",'age'],index = ["a","b","c","d"])
print(df)
# Out:
#        name  age
# 0    nikhil   10
# 1  devendra   20
# 2       raj   30
# 3     hello   40
#        name  age
# a    nikhil   10
# b  devendra   20
# c       raj   30
# d     hello   40

# %%
import pandas as pd
data = [['devendra',10],['nikhil',20],['raj',30],['hello',40]]
df = pd.DataFrame(data)
print(df)

# add cols name
df = pd.DataFrame(data,columns=['name','age'])
print(df)


# add indexing name
df = pd.DataFrame(data,index=['a','b','c','d'])
print(df)
# Out:
#           0   1
# 0  devendra  10
# 1    nikhil  20
# 2       raj  30
# 3     hello  40
#        name  age
# 0  devendra   10
# 1    nikhil   20
# 2       raj   30
# 3     hello   40
#           0   1
# a  devendra  10
# b    nikhil  20
# c       raj  30
# d     hello  40

# %%
# github csv


import pandas as pd

url   =   "https://raw.githubusercontent.com/gungungoyal314/PythonLearn/main/file.csv"
df = pd.read_csv(url)
print(df)
# Out:
#        name gender
# 0    nikhil   male
# 1       raj   male
# 2  devendra   male
# 3     hello   male

# %%
# github excel
import pandas as pd
url = "https://raw.githubusercontent.com/gungungoyal314/PythonLearn/main/file.xlsx"
df = pd.read_excel(url)
print(df)
# Out:
#        name gender
# 0    nikhil   male
# 1       raj   male
# 2  devendra   male
# 3     hello   male

# %%
# github json
import pandas as pd
url = "https://raw.githubusercontent.com/gungungoyal314/PythonLearn/main/data.json"
df = pd.read_json(url)
print(df)
# Out:
#        name  age
# 0    nikhil   10
# 1  devendra   20
# 2       raj   30
# 3     hello   40

# %%
# json to excel
import pandas as pd
url = "https://raw.githubusercontent.com/gungungoyal314/PythonLearn/main/data.json"
df = pd.read_json(url)
df.to_excel("data.xlsx")

# %%
# github excel
import pandas as pd
url = "https://raw.githubusercontent.com/Abhii009/Learn-Python/main/file.xlsx"
df = pd.read_excel(url)
print(df)
# Out:
#        name gender
# 0    nikhil   male
# 1       raj   male
# 2  devendra   male
# 3     hello   male

# %%
# github json
import pandas as pd
url = "https://raw.githubusercontent.com/Abhii009/Learn-Python/main/data.json"
df = pd.read_json(url)
print(df)
# Out:
#        name  age
# 0    nikhil   10
# 1  devendra   20
# 2       raj   30
# 3     hello   40

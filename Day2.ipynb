# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhii009/Learn-Python/blob/main/Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("abhishek")
# Out:
# abhishek

# %%
#explicit
#implicit

# %%
#operator
'''1. arith -> +,-,*,/,//,%,**
2. relational -> >,<.>=,<=,==,!=
3. assignment -> +=, -+,*=,%=
4. logical ->  and, or, not
5. bitwise -> &, | '''
# Out:
# '1. arith -> +,-,*,/,//,%,**\n2. relational -> >,<.>=,<=,==,!=\n3. assignment -> +=, -+,*=,%=\n4. logical ->  and, or, not\n5. bitwise -> &, | '

# %%
#arithmatic operator
num1 = 10
num2 = 20
print(num1+num2)
print(num1-num2)
print(num1*num2)
print(num1/num2)
print(num1//num2)
print(num1%num2)
# Out:
# 30
# -10
# 200
# 0.5
# 0
# 10

# %%
num1 = 34
num2 = 89
print(num1*num2)
print(num1/num2)
print(num1//num2)
print(num1%num2)
# Out:
# 3026
# 0.38202247191011235
# 0
# 34

# %%
num1 = 45
num2 = 2
print (num1 - num2)
# Out:
# 43

# %%
num1 = 20
num2 = 5
print(num1 % num2)
# Out:
# 0

# %%
print (10//3)
print(10.0//3.0) #double forward give output in integer || Quotient
# Out:
# 3
# 3.0

# %%
print(5**2)
# Out:
# 25

# %%
# relational operators (true/false)
num1 = 10
num2 = 30
print (num1 > num2)
# Out:
# False

# %%
num1 = 34
num2 = 33
print (num1 <= num2)
# Out:
# False

# %%
num1 = 76
num2 = 65
print (num1 >= num2)
print (num1 <= num2)
print (num1 > num2)
print (num1 < num2)
print (num1 == num2)
print (num1 != num2)
# Out:
# True
# False
# True
# False
# False
# True

# %%
#assignment operator
num1 = 10
num2 = 20
num1 += num2
print(num1)
# Out:
# 30

# %%
num1 = 400
num2 = 20
num1 -= num2
print(num1)
num1 *= num2
print(num1)
num1 /= num2
print(num1)
num1 %= num2
print(num1)
num1 //= num2
print(num1)
num1 **= num2
print(num1)
# Out:
# 380
# 7600
# 380.0
# 0.0
# 0.0
# 0.0

# %%
#logical opr
print(True and True)
print(True and False)
print(False and True)
print(False and False)
print(True or True)
print(True or False)
print(False or True)
print(False or False)
print(not True)
print(not False)
# Out:
# True
# False
# False
# False
# True
# True
# True
# False
# False
# True

# %%
num1 = 20 #if the first num1 is 0 than condition always false.
num2 = 40
print(num1 and num2 )
num1 = 20
num2 = 40
print(num1 or num2 )
num1 = 20
num2 = 40
print(not num1 )
# Out:
# 40
# 20
# False

# %%
num1 = ""
num2 = 30
print (num1 and num2)

# %%
data = [0, 1, False, "Apples", ""]
filtered = [x for x in data if not x or type(x) == str]
print(filtered)
# Out:
# [0, False, 'Apples', '']

# %%
a = 10
b = 20
c = 30
print(not(a < b and b > c or c > a))
# Out:
# False

# %%
a = 'hello'
b = 5
c = []
print (a and b and c)
# Out:
# []

# %%
#bitwise
num1 = 5
num2 = 4
print(num1 & num2)
# Out:
# 4

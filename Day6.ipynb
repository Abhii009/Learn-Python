# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhii009/Learn-Python/blob/main/Day6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("abhi")
# Out:
# abhi

# %%
#opps in python
class Student:
  name = "Abhishek"
  roll_no = 5

s = Student() #object
print(s.name) #attribute
print(s.roll_no) #attribute
# Out:
# Abhishek
# 5

# %%
class Student:
 def __init__(self, name, roll_no): #constructor | self -> this
  self.name = name
  self.roll_no = roll_no
s = Student ("abhishek",5)
print(s.name)
print(s.roll_no)
#self is not compulsary we can use any word instead of this
# Out:
# abhishek
# 5

# %%
class Student:
    def __init__(this, name, roll_no, age): #constructor | __init__ change nhi kar sakte hai
      this.name = name
      this.roll_no = roll_no
      this.age = age

s = Student("abhishek",5,20)
print(s.name)
print(s.roll_no)
print(s.age)
# Out:
# abhishek
# 5
# 20

# %%
class Student:
   def __init__(this, name, age, roll_no):
     this.name = name
     this.age = age
     this.roll_no = roll_no

#s = Studnet("abhishek",123,20)
#print(s.name, s.roll_no,s.age)

s = Student(name='abhishek', age=20, roll_no=123)
print(s.name, s.roll_no,s.age)
# Out:
# abhishek 123 20

# %%
class Student:
  def __init__(this, name = 'Abhi', roll_no=56, age=None): #default values
    this.name = name
    this.roll_no = roll_no
    this.age = age

s = Student("Abhi",5)
print(s.name, s.roll_no,s.age)

#in the case apne pass kisi student ki age hai to
print(s1.name, s1.roll_no,s1.age)
s1 = Student("Mohit",1223,17)

#
s2 = Student()
print(s2.name, s2.roll_no,s2.age)  #ye function default values utha lega uper se  chahe yha s2 = Student blank ho
# Out:
# Abhi 5 None
# Mohit 1223 17
# Abhi 56 None

# %%
class Student:
  def __init__(this,*args):
    #print(type(args)) #type -> Tuple | immutable
    #print(args) #Tuple ('Abhishek', 55, 20)
    this.data = args


s = Student ("Abhishek", 55, 20)
print(s.data[0], s.data[1],s.data[2])
# Out:
# Abhishek 55 20

# %%
class Student:
  def __init__(self,*args):
   self.data = args
s = Student (["Bhupendra","Abhi", "Arya","Pareta"])
print(s.data[0][0])

#for i in s.data[0]:
  #print(i)
# Out:
# Bhupendra
# Abhi
# Arya
# Pareta

# %%
class Student:
   def __init__(self, *args):
     self.data = args

s = Student ({"users":["Bhupendra","Abhi"]}, {"address":{"Home_town":"kukas", "office":"jaipur"}})



for i in range(len(s.data[0]["users"])):
  #print(i)
  print(s.data[0]["users"][i])
  print(list(s.data[1]["address"].values())[i])
# Out:
# Bhupendra
# kukas
# Abhi
# jaipur

# %%
for i in range(len(s.data[0]["users"])):
  #print(i)
  print(s.data[0]["users"][i])
  print(list(s.data[1]["address"].values())[i])
# Out:
# Bhupendra
# kukas
# Abhi
# jaipur

# %%
class Student:
  def __init__(self,name,roll_no):
    self.name=name
    self.roll_no=roll_no

  #get
  def getName (self):
    print(self.name)

  #update
  def updateName(self):
    self.name="hello"
    print(self.name)

  #delete
  def deleteName(self):
    del self.name
    #print(self.name)

  #create
  def createName(self):
    self.name="hello"
    print(self.name)
s = Student("abhishek",5)
s.getName()
s.updateName()
s.deleteName()
s.createName()
# Out:
# abhishek
# hello
# hello

# %%
class Student:
  def __init__(self,name,roll_no):
    print("auto start")
    self.name = name
    self.roll_no = roll_no
  # get
  def updateName(self,name=None): # default value -> none
    if name != None:
      self.name = name
    print(self.name)


inst = Student("nikhil",123)
inst.updateName("rajendra")

inst1 = Student("abhishek",321)
inst1.updateName()
# Out:
# auto start
# rajendra
# auto start
# abhishek

# %%
#inheritance
class Student:
  def __init__(self,name,roll_no,city,state):
    self.name = name
    self.roll_no = roll_no
    self.city = city
    self.state = state
  def getDate(self):
   print(self.name, self.roll_no, self.city, self.state)

class Address(Student):
  def __init__ (self, name,roll_no,city,state):
    self.city = city
    self.state = state
    super().__init__(name,roll_no,city,state) #inheritance

    #extra repeat
    #self.name = name
    #self.roll_no = roll_no
  def getAddress(self):
    print(self.city, self.state)

a = Address("Abhishek",123,"jaipur","rajasthan")
a.getDate()
# Out:
# Abhishek 123 jaipur rajasthan

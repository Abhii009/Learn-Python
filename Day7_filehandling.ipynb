# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhii009/Learn-Python/blob/main/Day7_filehandling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#fdle handling
#read
#write

# %%
from google.colab import drive
#mount = cloaning karna  | ab ye bar bar mount nhi karega
#drive.mount('/content/drive')

data = open("/content/drive/MyDrive/linux.csv", "r")
data.read()
# Out:
# ''

# %%
#read & write
data2 = open("/content/drive/MyDrive/Ram.txt", "w")
data2.write("we are Hacker \n")


data2 = open("/content/drive/MyDrive/Ram.txt", "r")
data2.read()
# Out:
# 'we are Hacker \n'

# %%
# read & append
data2 = open("/content/drive/MyDrive/Ram.txt", "r")
data2.read()

data2 = open("/content/drive/MyDrive/Ram.txt", "a")
data2.write("we are Hacker and Grrasian \n")

data2 = open("/content/drive/MyDrive/Ram.txt", "r")
data2.read()
# Out:
# 'we are Hacker \nwe are Hacker and Grrasian \n'

# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhii009/Learn-Python/blob/main/Day8numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
l = [1,2,3]
print(l)
# array
arr = np.array(l)
print(arr)

# print("hello")
# Out:
# [1, 2, 3]
# [1 2 3]

# %%
#numpy list
import numpy as np
import time as t

print(t.time())
# #for list
# start =  time.time()
# sum1 = 0
# for i in range(10000):
#   sum1 += i*2
# end = time.time()

# print("for list", sum1,end-start)

# #for numpy | array | array works on every element | element wise
# start1 = time.time()
# sum2 = 0
# arr = np.arange(100000)*2
# sum2 = arr.sum()
# end1 = time.time()

# print("for numpy", sum2,end1-start1)
# Out:
# 1781857698.9798849

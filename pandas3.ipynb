# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhii009/Learn-Python/blob/main/pandas3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# handle missing values
import pandas as pd
import numpy as np
data = {
    "experience":[1,2,3,4,5],
    "salary":[100,200,300,400,500]
}
df = pd.DataFrame(data)
print(df)
# Out:
#    experience  salary
# 0           1     100
# 1           2     200
# 2           3     300
# 3           4     400
# 4           5     500

# %%
import pandas as pd
import numpy as np
data = {
    "experience":[1,np.nan,3,4,5],
    "salary":[100,200,300,400,np.nan]
}
df = pd.DataFrame(data)
print(df)
# fill null values
df.isnull()


# sum of null values
df.isnull().sum()


# dropna
df.dropna()
print(df)

# fillna
df.fillna(5)
# Out:
#    experience  salary
# 0         1.0   100.0
# 1         NaN   200.0
# 2         3.0   300.0
# 3         4.0   400.0
# 4         5.0     NaN
#    experience  salary
# 0         1.0   100.0
# 1         NaN   200.0
# 2         3.0   300.0
# 3         4.0   400.0
# 4         5.0     NaN
#    experience  salary
# 0         1.0   100.0
# 1         5.0   200.0
# 2         3.0   300.0
# 3         4.0   400.0
# 4         5.0     5.0

# %%
# matplotlib
import matplotlib.pyplot as plt
data = {
    "experience":[1,2,3,4,5],
    "salary":[100,200,300,400,500],
}
x = data['experience']# matplotlib
import matplotlib.pyplot as plt
data = {
    "experience":[1,2,3,4,5],
    "salary":[100,200,300,400,500],
}
x = data['experience']
y = data['salary']
# plt.plot --> line chart
plt.plot(data["experience"],data["salary"],marker = '*',markersize = 14,color = 'pink')
plt.figure(figsize=(6,4))
plt.savefig("hello.jpeg")
plt.show()
y = data['salary']
# plt.plot --> line chart
plt.plot(data["experience"],data["salary"],marker = '*',markersize = 14,color = 'blue')
plt.show()

# %%
# pie chart
x = ['apple','banana','carrot','mango']
y = [30,50,70,5]

plt.figure(figsize=(4,4))
plt.pie(y,labels = x,autopct = "%1.1f%%",colors=['red','yellow','orange','green'])
plt.show()

# %%
# sub plot
import matplotlib.pyplot as plt
data = {
    "experience":[1,2,3,4,5],
    "salary":[100,200,300,400,500],
}
x = data['experience']
y = data['salary']
plt.pie(y,labels=x)
plt.plot(x,y)
plt.show()


x = ['apple','banana','carrot','mango']
y = [30,50,70,5]
plt.plot(x,y)
plt.pie(y,labels = x,autopct = "%1.1f%%",colors=['red','yellow','orange','green'])
plt.show()

# %%
# sub plot
import matplotlib.pyplot as plt
data = {
    "experience":[1,2,3,4,5],
    "salary":[100,200,300,400,500],
}
x = data['experience']
y = data['salary']
plt.pie(y,labels=x)
plt.plot(x,y)
plt.show()


x = ['apple','banana','carrot','mango']
y = [30,50,70,5]
plt.plot(x,y)
plt.pie(y,labels = x,autopct = "%1.1f%%",colors=['red','yellow','orange','green'])
plt.show()

# %%
# subplots
import matplotlib.pyplot as plt #
# pie chart data
x = ["apple","banana","carrot","mango"]
y = [30,50,70,5]
fig , aux = plt.subplots(1,2)
aux[0].pie(y,labels=x)

# line chart data
data = {
    "experience":[1,2,3,4,5],
    "salary":[100,200,300,400,500]
}
x = data['experience']
y = data['salary']

aux[1].plot(x,y)
plt.tight_layout()
plt.show()

# %%
# pie chart
x = ["apple","banana","carrot","mango"]
y = [30,50,70,5]
fig , aux = plt.subplots(2,2)
aux[0,0].pie(y,labels=x)

# line chart data
data = {
    "experience":[1,2,3,4,5],
    "salary":[100,200,300,400,500]
}
x = data['experience']
y = data['salary']
aux[0,1].plot(x,y)

# bar chart
x = ["apple","banana","carrot","mango"]
y = [30,50,70,5]
aux[1,0].bar(x,y)

# multiline chart
x = ["apple","banana","carrot","mango"]
y = [30,50,70,5]
aux[1,1].plot(x,y)
plt.tight_layout()
plt.show()
